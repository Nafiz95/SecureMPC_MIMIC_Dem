# %%
import pandas as pd
import time

# %%
patient = pd.read_csv('PATIENTS.csv')

# %%
prescription = pd.read_csv('PRESCRIPTIONS.csv')

# %%
patient
# Out:
#     row_id  subject_id gender                  dob                  dod  \
# 0     9467       10006      F  2094-03-05 00:00:00  2165-08-12 00:00:00
# 1     9472       10011      F  2090-06-05 00:00:00  2126-08-28 00:00:00
# 2     9474       10013      F  2038-09-03 00:00:00  2125-10-07 00:00:00
# 3     9478       10017      F  2075-09-21 00:00:00  2152-09-12 00:00:00
# 4     9479       10019      M  2114-06-20 00:00:00  2163-05-15 00:00:00
# ..     ...         ...    ...                  ...                  ...
# 95   31838       44083      M  2057-11-15 00:00:00  2114-02-20 00:00:00
# 96   31853       44154      M  1878-05-14 00:00:00  2178-05-15 00:00:00
# 97   31867       44212      F  2078-06-16 00:00:00  2124-01-29 00:00:00
# 98   31870       44222      M  2107-06-27 00:00:00  2182-08-03 00:00:00
# 99   31872       44228      F  2112-10-22 00:00:00  2171-04-14 00:00:00
#
#                dod_hosp              dod_ssn  expire_flag
# 0   2165-08-12 00:00:00  2165-08-12 00:00:00            1
# 1   2126-08-28 00:00:00                  NaN            1
# 2   2125-10-07 00:00:00  2125-10-07 00:00:00            1
# 3                   NaN  2152-09-12 00:00:00            1
# 4   2163-05-15 00:00:00  2163-05-15 00:00:00            1
# ..                  ...                  ...          ...
# 95  2114-02-20 00:00:00  2114-02-20 00:00:00            1
# 96  2178-05-15 00:00:00  2178-05-15 00:00:00            1
# 97                  NaN  2124-01-29 00:00:00            1
# 98  2182-08-03 00:00:00                  NaN            1
# 99  2171-04-14 00:00:00                  NaN            1
#
# [100 rows x 8 columns]

# %%
prescription
# Out:
#         row_id  subject_id  hadm_id  icustay_id            startdate  \
# 0        32600       42458   159647         NaN  2146-07-21 00:00:00
# 1        32601       42458   159647         NaN  2146-07-21 00:00:00
# 2        32602       42458   159647         NaN  2146-07-21 00:00:00
# 3        32603       42458   159647         NaN  2146-07-21 00:00:00
# 4        32604       42458   159647         NaN  2146-07-21 00:00:00
# ...        ...         ...      ...         ...                  ...
# 10393  3609913       42430   100969    210474.0  2142-11-29 00:00:00
# 10394  3609914       42430   100969    210474.0  2142-11-30 00:00:00
# 10395  3609915       42430   100969         NaN  2142-11-26 00:00:00
# 10396  3609916       42430   100969         NaN  2142-11-26 00:00:00
# 10397  3609917       42430   100969         NaN  2142-11-26 00:00:00
#
#                    enddate drug_type                         drug  \
# 0      2146-07-22 00:00:00      MAIN  Pneumococcal Vac Polyvalent
# 1      2146-07-22 00:00:00      MAIN                    Bisacodyl
# 2      2146-07-22 00:00:00      MAIN                    Bisacodyl
# 3      2146-07-22 00:00:00      MAIN                        Senna
# 4      2146-07-21 00:00:00      MAIN     Docusate Sodium (Liquid)
# ...                    ...       ...                          ...
# 10393  2142-11-30 00:00:00      MAIN  Sodium Chloride 0.9%  Flush
# 10394  2142-11-30 00:00:00      MAIN                Acetaminophen
# 10395  2142-11-27 00:00:00      BASE         0.9% Sodium Chloride
# 10396  2142-11-27 00:00:00      BASE                          D5W
# 10397  2142-11-28 00:00:00      BASE        0.83% Sodium Chloride
#
#                      drug_name_poe            drug_name_generic  \
# 0      Pneumococcal Vac Polyvalent  PNEUMOcoccal Vac Polyvalent
# 1                        Bisacodyl                    Bisacodyl
# 2                        Bisacodyl           Bisacodyl (Rectal)
# 3                            Senna                        Senna
# 4         Docusate Sodium (Liquid)     Docusate Sodium (Liquid)
# ...                            ...                          ...
# 10393  Sodium Chloride 0.9%  Flush  Sodium Chloride 0.9%  Flush
# 10394                Acetaminophen       Acetaminophen (Rectal)
# 10395                          NaN                          NaN
# 10396                          NaN                          NaN
# 10397                          NaN                          NaN
#
#       formulary_drug_cd      gsn          ndc     prod_strength dose_val_rx  \
# 0               PNEU25I  48548.0    6494300.0  25mcg/0.5mL Vial         0.5
# 1                 BISA5   2947.0  536338101.0          5 mg Tab          10
# 2               BISA10R   2944.0  574705050.0  10mg Suppository          10
# 3               SENN187  19964.0  904516561.0          1 Tablet           1
# 4              DOCU100L   3017.0  121054410.0      100mg UD Cup         100
# ...                 ...      ...          ...               ...         ...
# 10393         NACLFLUSH      NaN          0.0           Syringe           3
# 10394          ACET650R   4478.0  713016550.0        650mg Supp         650
# 10395            NS1000   1210.0  338004904.0        1000mL Bag        1000
# 10396           HEPBASE      NaN          0.0      HEPARIN BASE         250
# 10397     NICABAGSODCHL      NaN          0.0        200 mL Bag         200
#
#       dose_unit_rx form_val_disp form_unit_disp    route
# 0               mL             1           VIAL       IM
# 1               mg             2            TAB       PO
# 2               mg             1           SUPP       PR
# 3              TAB             1            TAB       PO
# 4               mg             1          UDCUP       PO
# ...            ...           ...            ...      ...
# 10393           mL           0.6            SYR       IV
# 10394           mg             1           SUPP       PR
# 10395           mL             1            BAG       IV
# 10396           mL           250             mL       IV
# 10397           mL             1            BAG  IV DRIP
#
# [10398 rows x 19 columns]

# %%
dose_val_rx=prescription.dose_val_rx.tolist()

# %%
eval('5-10')

# %%
doses = []
for i in prescription.dose_val_rx.tolist():
    try:
        if eval(i)>0:
            doses.append(int(eval(i)))
    except:
        pass

# %%
len(doses)
# Out:
# 9522

# %%
patient_list = patient.index.tolist()[3:]

# %% [markdown]
# ## Initiations

# %%
from mpyc.runtime import mpc    # load MPyC
secint = mpc.SecInt()           # 32-bit secure MPyC integers
mpc.run(mpc.start())            # required only when run with multiple parties
import traceback                # to show some suppressed error messages

# %% [markdown]
# ## Secure Additions of Treatment Doses

# %%
#Checking with normal summation
start_time = time.time()

total_dose = sum(doses)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
start_time = time.time()
x = list(map(secint, doses))
summation = secint(0)
for i in x:
    summation+=i
print("--- %s seconds ---" % (time.time() - start_time))

# %%
mpc.run(mpc.shutdown())   # required only when run with multiple parties

# %% [markdown]
# ### Secure Permute Patients

# %%
from mpyc.runtime import mpc    # load MPyC
secint = mpc.SecInt()           # 32-bit secure MPyC integers
mpc.run(mpc.start())            # required only when run with multiple parties
import traceback                # to show some suppressed error messages
# Out:
# 2022-12-06 16:11:43,987 Start MPyC runtime v0.8

# %%
@mpc.coroutine                                      # turn coroutine into an MPyC coroutine
async def random_unit_vector(n):                    # returns list of n secint elements
    await mpc.returnType(secint, n)                 # set return type of this MPyC coroutine
    if n == 1: 
        return [secint(1)]
    b = mpc.random_bit(secint)                      # pick one random bit if n>=2
    x = random_unit_vector((n + 1) // 2)            # recursive call with m=(n+1)//2
    if n % 2 == 0:
        y = mpc.scalar_mul(b, x)                    # y = [0]*m or y = x
        return y + mpc.vector_sub(x, y)             # [0]*m + x or x + [0]*m
    elif await mpc.eq_public(b * x[0], 1):          # reject if b=1 and x[0]=1
        return random_unit_vector(n)                # start over
    else:
        y = mpc.scalar_mul(b, x[1:])                # y = [0]*m or y = x[1:] 
        return x[:1] + y + mpc.vector_sub(x[1:], y) # [x[0]]  + ([0]*m + x[1:] or [0]*m + x[1:])

def random_permutation(n):                     # returns list of n secint elements
    p = [secint(i) for i in range(n)]          # initialize p to identity permutation
    for i in range(n-1):
        x_r = random_unit_vector(n-i)          # x_r = [0]*(r-i) + [1] + [0]*(n-1-r), i <= r < n
        p_r = mpc.in_prod(p[i:], x_r)          # p_r = p[r]
        d_r = mpc.scalar_mul(p[i] - p_r, x_r)  # d_r = [0]*(r-i) + [p[i] - p[r]] + [0]*(n-1-r)
        p[i] = p_r                             # p[i] = p[r]
        for j in range(n-i):
            p[i+j] += d_r[j]                   # p[r] = p[r} + p[i] - p[r] = p[i]
    return p                                

@mpc.coroutine                                    # turn coroutine into an MPyC coroutine
async def random_derangement(n):                  # returns list of n secint elements
    await mpc.returnType(secint, n)               # set return type of this MPyC coroutine
    p = random_permutation(n)
    t = mpc.prod([p[i] - i for i in range(n)])    # securely multiply all differences p[i] - i
    if await mpc.is_zero_public(t):               # publicly test whether t is equal to zero
        return random_derangement(n)              # recurse if t is zero
    else:
        return p                                  # done if t is nonzero

# %%
print('Random derangements:')
for n in patient_list:
    s = mpc.run(mpc.output(random_derangement(n)))
    print(f'{n:2} {s}')
# Out:
# Random derangements:
#  3 [1, 2, 0]
#  4 [3, 2, 0, 1]
#  5 [4, 0, 3, 2, 1]
#  6 [4, 5, 0, 2, 1, 3]
#  7 [2, 4, 1, 0, 3, 6, 5]
#  8 [4, 3, 7, 6, 2, 0, 5, 1]
#  9 [1, 8, 0, 5, 3, 7, 4, 2, 6]
# 10 [5, 7, 8, 9, 2, 3, 4, 6, 1, 0]
# 11 [10, 9, 0, 2, 8, 3, 1, 5, 4, 7, 6]
# 12 [5, 2, 1, 0, 9, 11, 8, 4, 7, 6, 3, 10]
# 13 [11, 6, 8, 12, 3, 2, 4, 9, 10, 5, 1, 7, 0]
# 14 [8, 7, 10, 13, 6, 0, 12, 11, 9, 4, 3, 2, 1, 5]
# 15 [14, 2, 13, 7, 12, 4, 3, 5, 1, 10, 11, 6, 9, 0, 8]
# 16 [3, 15, 0, 13, 8, 6, 14, 10, 7, 4, 12, 9, 11, 2, 5, 1]
# 17 [13, 11, 6, 16, 10, 3, 15, 4, 9, 5, 12, 14, 2, 0, 1, 8, 7]
# 18 [6, 15, 11, 13, 1, 3, 4, 9, 12, 2, 17, 7, 0, 16, 10, 8, 14, 5]
# 19 [1, 18, 9, 5, 13, 11, 8, 6, 14, 0, 2, 10, 16, 4, 7, 17, 3, 15, 12]
# 98 [72, 38, 14, 59, 16, 57, 2, 27, 97, 55, 25, 21, 8, 29, 37, 89, 15, 65, 24, 0, 96, 35, 81, 13, 23, 4, 43, 80, 5, 31, 94, 26, 95, 74, 91, 73, 11, 86, 69, 33, 39, 77, 63, 70, 18, 67, 49, 71, 79, 82, 34, 60, 83, 61, 90, 20, 42, 66, 54, 19, 52, 12, 28, 45, 22, 3, 10, 47, 76, 64, 68, 53, 75, 44, 78, 32, 85, 41, 88, 92, 1, 40, 46, 9, 7, 36, 56, 50, 48, 87, 84, 58, 93, 30, 51, 17, 62, 6]
# 99 [2, 73, 25, 48, 64, 72, 47, 63, 83, 12, 17, 95, 44, 56, 24, 79, 4, 22, 70, 13, 59, 0, 58, 69, 42, 91, 7, 37, 66, 61, 21, 14, 71, 38, 55, 68, 77, 43, 78, 82, 54, 76, 8, 52, 11, 32, 53, 31, 9, 36, 41, 93, 75, 33, 29, 19, 65, 60, 89, 16, 51, 49, 35, 94, 85, 74, 84, 50, 30, 86, 92, 45, 96, 67, 80, 97, 18, 87, 10, 20, 23, 98, 3, 90, 57, 34, 62, 39, 28, 6, 26, 1, 27, 15, 81, 5, 88, 40, 46]

# %%
mpc.run(mpc.shutdown())   # required only when run with multiple parties
# Out:
# 2022-12-06 17:08:57,358 Stop MPyC runtime -- elapsed time: 0:08:03.304565

# %% [markdown]
# ## Secure OT

# %%
patient_id = patient.subject_id
pres_id = prescription.hadm_id.unique().tolist()

# %%
len(patient_id),len(pres_id)
# Out:
# (100, 122)

# %%
from mpyc.runtime import mpc    # load MPyC
secint = mpc.SecInt()           # 32-bit secure MPyC integers
mpc.run(mpc.start())            # required only when run with multiple parties
import traceback      

import random
import sys
# Out:
# 2022-12-06 17:09:09,380 Start MPyC runtime v0.8

# %%
m = len(mpc.parties)
if m%2 == 0:
    print('OT runs with odd number of parties only.')
    sys.exit()

# %%
t = m//2
message = [(None, None)] * t
choice = [None] * t

# %%
if mpc.pid == 0:
    print('You are the trusted third party.')
elif 1 <= mpc.pid <= t:
    message[mpc.pid - 1] = (patient_id, pres_id)
    print(f'You are sender {mpc.pid} holding messages '
          f'{message[mpc.pid - 1][0]} and {message[mpc.pid - 1][1]}.')
else:
    choice[mpc.pid - t - 1] = 0 # 0->patient id, 1->pres id
    print(f'You are receiver {mpc.pid - t} with random choice bit {choice[mpc.pid - t - 1]}.')
# Out:
# You are the trusted third party.

# %%
message[mpc.pid-1] = (patient_id, pres_id)
print(f'You are sender {mpc.pid} holding messages '
    f'{message[mpc.pid - 1][0]} and {message[mpc.pid - 1][1]}.')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 message[mpc.pid-1] = (patient_id, pres_id)
#       2 print(f'You are sender {mpc.pid} holding messages '
#       3     f'{message[mpc.pid - 1][0]} and {message[mpc.pid - 1][1]}.')
#
# IndexError: list assignment index out of range

# %%
mpc.pid = 0
